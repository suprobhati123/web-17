# %% [markdown]
# IMPORT THE DATA

# %%
import pandas as pd
df=pd.read_csv("temperature.csv")
print (df)
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.shape
# Out:
# (7752, 25)

# %% [markdown]
# 7752 rows and 25 columns

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# FEATURE ENGINEERING

# %%
df['Date1']=df['Date'].str.split('-').str[0]
df['Date2']=df['Date'].str.split('-').str[1]
df['Date3']=df['Date'].str.split('-').str[2]

# %%
df=df.drop(['Date'],axis=1)

# %%
df['Date1'].isnull().sum()
# Out:
# 2

# %%
df['Date1'].fillna(df['Date1'].value_counts().index[0],inplace=True)

# %%
df['Date1'].isnull().sum()
# Out:
# 0

# %%
df['Date2'].isnull().sum()
# Out:
# 2

# %%
df['Date2'].fillna(df['Date2'].value_counts().index[0],inplace=True)

# %%
df['Date2'].isnull().sum()
# Out:
# 0

# %%
df['Date3'].isnull().sum()
# Out:
# 2

# %%
df['Date3'].fillna(df['Date3'].value_counts().index[0],inplace=True)

# %%
df['Date3'].isnull().sum()
# Out:
# 0

# %%
df['Date1']=df['Date1'].astype(int)

# %%
df['Date2']=df['Date2'].astype(int)

# %%
df['Date3']=df['Date3'].astype(int)

# %%
df.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#        lat      lon       DEM   Slope  Solar radiation  Next_Tmax  Next_Tmin  \
# ...

# %% [markdown]
# CHECKING NULL VALUES

# %%
df.isnull().sum()
# Out:
# station              2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# Date1                0
# Date2                0
# Date3                0
# dtype: int64

# %%
df['station'].fillna(df['station'].value_counts().index[0],inplace=True)
df['Present_Tmax'].fillna(df['Present_Tmax'].value_counts().index[0],inplace=True)
df['Present_Tmin'].fillna(df['Present_Tmin'].value_counts().index[0],inplace=True)
df['LDAPS_RHmin'].fillna(df['LDAPS_RHmin'].value_counts().index[0],inplace=True)
df['LDAPS_RHmax'].fillna(df['LDAPS_RHmax'].value_counts().index[0],inplace=True)
df['LDAPS_Tmax_lapse'].fillna(df['LDAPS_Tmax_lapse'].value_counts().index[0],inplace=True)
df['LDAPS_WS'].fillna(df['LDAPS_WS'].value_counts().index[0],inplace=True)
df['LDAPS_LH'].fillna(df['LDAPS_LH'].value_counts().index[0],inplace=True)
df['LDAPS_CC1'].fillna(df['LDAPS_CC1'].value_counts().index[0],inplace=True)
df['LDAPS_CC2'].fillna(df['LDAPS_CC2'].value_counts().index[0],inplace=True)
df['LDAPS_CC3'].fillna(df['LDAPS_CC3'].value_counts().index[0],inplace=True)
df['LDAPS_CC4'].fillna(df['LDAPS_CC4'].value_counts().index[0],inplace=True)
df['LDAPS_PPT1'].fillna(df['LDAPS_PPT1'].value_counts().index[0],inplace=True)
df['LDAPS_PPT2'].fillna(df['LDAPS_PPT2'].value_counts().index[0],inplace=True)
df['LDAPS_PPT3'].fillna(df['LDAPS_PPT3'].value_counts().index[0],inplace=True)
df['LDAPS_PPT4'].fillna(df['LDAPS_PPT4'].value_counts().index[0],inplace=True)

df['Next_Tmax'].fillna(df['Next_Tmax'].value_counts().index[0],inplace=True)
df['Next_Tmin'].fillna(df['Next_Tmin'].value_counts().index[0],inplace=True)

# %%
df['LDAPS_Tmin_lapse'].fillna(df['LDAPS_Tmin_lapse'].value_counts().index[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# station             0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# Date1               0
# Date2               0
# Date3               0
# dtype: int64

# %% [markdown]
# SPLITTING INTO X AND Y

# %% [markdown]
# FOR DETERMING NEXT Tmax

# %%
x1=df.drop("Next_Tmax",axis=1)
y1=df["Next_Tmax"]
x1.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#    LDAPS_PPT4      lat      lon       DEM   Slope  Solar radiation  Next_Tmin  \
# ...

# %% [markdown]
# FOR NEXT Tmin

# %%
x2=df.drop("Next_Tmin",axis=1)
y2=df["Next_Tmin"]
x2.head()
# Out:
#    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0          28.7          21.4    58.255688    91.116364
# 1      2.0          31.9          21.6    52.263397    90.604721
# 2      3.0          31.6          23.3    48.690479    83.973587
# 3      4.0          32.0          23.4    58.239788    96.483688
# 4      5.0          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  LDAPS_CC1  ...  \
# 0         28.074101         23.006936  6.818887   69.451805   0.233947  ...
# 1         29.850689         24.035009  5.691890   51.937448   0.225508  ...
# 2         30.091292         24.565633  6.138224   20.573050   0.209344  ...
# 3         29.704629         23.326177  5.650050   65.727144   0.216372  ...
# 4         29.113934         23.486480  5.735004  107.965535   0.151407  ...
#
#    LDAPS_PPT4      lat      lon       DEM   Slope  Solar radiation  Next_Tmax  \
# ...

# %% [markdown]
# SCALING

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
scaled = mms.fit_transform(df)
print(scaled)
# Out:
# [[0.         0.49431818 0.54301075 ... 0.96666667 0.         0.        ]
#  [0.04166667 0.67613636 0.55376344 ... 0.96666667 0.         0.        ]
#  [0.08333333 0.65909091 0.64516129 ... 0.96666667 0.         0.        ]
#  ...
#  [1.         0.18181818 0.32795699 ... 0.96666667 1.         1.        ]
#  [1.         0.         0.         ... 0.96666667 0.5        0.75      ]
#  [1.         1.         1.         ... 0.96666667 0.5        0.75      ]]

# %% [markdown]
# LINEAR REGRESSION FOR NEXT Tmax

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

for i in range(0,100):
    x1_train, x1_test,y1_train,y1_test = train_test_split(x1, y1, test_size=0.33, random_state=i)
    lr=LinearRegression()
    lr.fit(x1_train,y1_train)
    pred_train=lr.predict(x1_train)
    pred_test=lr.predict(x1_test)
    print(f"at random state {i} the training accuracy is:-{r2_score (y1_train,pred_train)}")
    print(f"at random state {i} the testing accuracy is:-{r2_score (y1_test,pred_test)}")
    print("\n")
# Out:
# at random state 0 the training accuracy is:-0.7831308968466344
# at random state 0 the testing accuracy is:-0.799323391532124
#
#
# at random state 1 the training accuracy is:-0.7916995117306019
# at random state 1 the testing accuracy is:-0.7808295340030881
#
#
# at random state 2 the training accuracy is:-0.7922099737926104
# at random state 2 the testing accuracy is:-0.7805397031143396
#
#
# at random state 3 the training accuracy is:-0.7890533247444345
# at random state 3 the testing accuracy is:-0.7874528141875894
#
#
# at random state 4 the training accuracy is:-0.7831772976893882
# at random state 4 the testing accuracy is:-0.7991400501430767
#
#
# at random state 5 the training accuracy is:-0.7892367307563278
# at random state 5 the testing accuracy is:-0.7870335514519251
#
#
# at random state 6 the training accuracy is:-0.7843960079644081
# at random state 6 the testing accuracy is:-0.7971709208937913
#
#
# at random state 7 the training accuracy is:-0.7885773399606552
# ...

# %%
x2_train, x2_test,y2_train,y2_test = train_test_split(x2, y2, test_size=0.33, random_state=4)

# %%
lr.fit(x2_train,y2_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x2_test)

# %%
print(r2_score (y2_test,pred_test))
# Out:
# 0.843151273910932

# %% [markdown]
# FOR NEXT Tmin

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

for i in range(0,100):
    x2_train, x2_test,y2_train,y2_test = train_test_split(x2, y2, test_size=0.33, random_state=i)
    lr=LinearRegression()
    lr.fit(x2_train,y2_train)
    pred_train=lr.predict(x2_train)
    pred_test=lr.predict(x2_test)
    print(f"at random state {i} the training accuracy is:-{r2_score (y2_train,pred_train)}")
    print(f"at random state {i} the testing accuracy is:-{r2_score (y2_test,pred_test)}")
    print("\n")
# Out:
# at random state 0 the training accuracy is:-0.8320530592326305
# at random state 0 the testing accuracy is:-0.8401690457772022
#
#
# at random state 1 the training accuracy is:-0.8365010246092832
# at random state 1 the testing accuracy is:-0.8308233364889522
#
#
# at random state 2 the training accuracy is:-0.8364756019249635
# at random state 2 the testing accuracy is:-0.8314878491334546
#
#
# at random state 3 the training accuracy is:-0.8337855801677785
# at random state 3 the testing accuracy is:-0.8363061665365571
#
#
# at random state 4 the training accuracy is:-0.8306047660595566
# at random state 4 the testing accuracy is:-0.843151273910932
#
#
# at random state 5 the training accuracy is:-0.8345030237966978
# at random state 5 the testing accuracy is:-0.835190146733099
#
#
# at random state 6 the training accuracy is:-0.8325444503766333
# at random state 6 the testing accuracy is:-0.8391764577812005
#
#
# at random state 7 the training accuracy is:-0.8343080400921371
# ...

# %%
x2_train, x2_test,y2_train,y2_test = train_test_split(x2, y2, test_size=0.33, random_state=30)

# %%
lr.fit(x2_train,y2_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x2_test)

# %%
print(r2_score (y2_test,pred_test))
# Out:
# 0.8423185876180054

# %% [markdown]
# LASSO FOR NEXT Tmax

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import Lasso
parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state':(range(0,10))}
ls= Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x1_train,y1_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls = Lasso(alpha=.0001,random_state=0)
ls.fit(x1_train,y1_train)
ls.score(x1_train,y1_train)
pred_ls = ls.predict(x1_test)
lss = r2_score(y1_test,pred_ls)
lss
# Out:
# 0.7835833376154107

# %% [markdown]
# LASSO FOR NEXT TmIN

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import Lasso
parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state':(range(0,10))}
ls= Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(x2_train,y2_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls = Lasso(alpha=.0001,random_state=0)
ls.fit(x2_train,y2_train)
ls.score(x2_train,y2_train)
pred_ls = ls.predict(x2_test)
lss = r2_score(y2_test,pred_ls)
lss
# Out:
# 0.8423025464139129

# %% [markdown]
# RANDOM FOREST FOR NEXTMax

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x1_train,y1_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
rf = RandomForestRegressor(criterion="mae",max_features="sqrt")
rf.fit(x1_train,y1_train)
rf.score(x1_train,y1_train)
pred_rf = rf.predict(x1_test)
rfs = r2_score(y1_test,pred_rf)
print('R2 Score:', rfs*100)
rfscore = cross_val_score(rf,x1,y1,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 90.58358474860063
# Cross Val Score: 69.53304398940304

# %% [markdown]
# RANDOM FOREST FOR NEXTMin

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
rf = RandomForestRegressor()
clf = GridSearchCV(rf,parameters)
clf.fit(x2_train,y2_train)
print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score
rf = RandomForestRegressor(criterion="mse",max_features="log2")
rf.fit(x2_train,y2_train)
rf.score(x2_train,y2_train)
pred_rf = rf.predict(x2_test)
rfs = r2_score(y2_test,pred_rf)
print('R2 Score:', rfs*100)
rfscore = cross_val_score(rf,x2,y2,cv=5)
rfc = rfscore.mean()
print('Cross Val Score:',rfc*100)
# Out:
# R2 Score: 91.8265986958223
# Cross Val Score: 76.0298248843674

# %% [markdown]
# BEST MODEL RANDOM FOREST WITH 91% R2 SCORE
